# %%
import statistics
set1 = [1,3,3,4,5]
#1,3,3,4,5
print("median of the set is",(statistics.median_high(set1)))
# Out:
# median of the set is 3

# %%
import statistics
set1 = [1,2,8,4,5]
#1,1,2,4,5,8
print("low median of the vset is ",(statistics.median_low(set1)))
# Out:
# low median of the vset is  4

# %%
l1 = [10,20,"phython",94.3,314]
l1.append(21)
print(l1)
# Out:
# [10, 20, 'phython', 94.3, 314, 21]
